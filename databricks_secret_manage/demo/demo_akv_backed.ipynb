# %%
account_key = dbutils.secrets.get("kaninipro_secret_scope","rawdata-secret")
spark.conf.set("fs.azure.account.key.rawdatastorage123456.dfs.core.windows.net", account_key)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, TimestampType
from pyspark.sql.functions import col

schema = StructType([
    StructField("id", IntegerType(), True),
    StructField("name", StringType(), True),
    StructField("age", StringType(), True)
])

people_df = spark.read.format("csv")\
    .option("header","true")\
    .schema(schema) \
    .load("abfss://data@rawdatastorage123456.dfs.core.windows.net/people/people.csv")

# %%
display(people_df)
